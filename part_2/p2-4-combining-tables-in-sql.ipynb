# %% [markdown]
# # Part 2.4: Combining Tables in SQL Course

# %% [markdown]
# Importing sqlite3 to run queries in python:

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# Connecting to the database and creating a cursor object:

# %%
connection = sqlite3.connect('chinook.db')
cursor = connection.cursor()

# %% [markdown]
# ## Introduction to Joins

# %% [markdown]
# Joining Tables:

# %%
query = """

SELECT
    -- All columns
    *
FROM
    -- customer table
    customer
INNER JOIN
    -- join the columns of the invoice table
    invoice
    -- matching rows based on customer_id in the first table and customer_id in the second table
    ON customer.customer_id = invoice.customer_id
LIMIT
    -- Display top 5 rows
    5;

"""

pd.read_sql_query(query,connection)
# Out:
#    customer_id first_name last_name company           address      city state  \
# 0           18   Michelle    Brooks    None      627 Broadway  New York    NY
# 1           30     Edward   Francis    None  230 Elgin Street    Ottawa    ON
# 2           40  Dominique  Lefebvre    None    8, Rue Hanovre     Paris  None
# 3           18   Michelle    Brooks    None      627 Broadway  New York    NY
# 4           27    Patrick      Gray    None   1033 N Park Ave    Tucson    AZ
#
#   country postal_code               phone  ... support_rep_id invoice_id  \
# 0     USA  10012-2612   +1 (212) 221-3546  ...              3          1
# 1  Canada     K2P 1L7   +1 (613) 234-3322  ...              3          2
# 2  France       75002  +33 01 47 42 71 71  ...              4          3
# 3     USA  10012-2612   +1 (212) 221-3546  ...              3          4
# 4     USA       85719   +1 (520) 622-4200  ...              4          5
#
#    customer_id         invoice_date   billing_address billing_city  \
# 0           18  2017-01-03 00:00:00      627 Broadway     New York
# 1           30  2017-01-03 00:00:00  230 Elgin Street       Ottawa
# 2           40  2017-01-05 00:00:00    8, Rue Hanovre        Paris
# 3           18  2017-01-06 00:00:00      627 Broadway     New York
# 4           27  2017-01-07 00:00:00   1033 N Park Ave       Tucson
#
#   billing_state billing_country billing_postal_code  total
# 0            NY             USA          10012-2612  15.84
# 1            ON          Canada             K2P 1L7   9.90
# 2          None          France               75002   1.98
# 3            NY             USA          10012-2612   7.92
# 4            AZ             USA               85719  16.83
#
# [5 rows x 22 columns]

# %% [markdown]
# Selecting Columns:

# %%
query = """

SELECT 
    customer.customer_id,first_name,last_name,email,invoice_id,invoice_date,total
FROM 
    customer
INNER JOIN 
    invoice
    ON customer.customer_id = invoice.customer_id;

"""

pd.read_sql_query(query,connection)
# Out:
#      customer_id first_name last_name                        email  \
# 0             18   Michelle    Brooks            michelleb@aol.com
# 1             30     Edward   Francis          edfrancis@yachoo.ca
# 2             40  Dominique  Lefebvre  dominiquelefebvre@gmail.com
# 3             18   Michelle    Brooks            michelleb@aol.com
# 4             27    Patrick      Gray         patrick.gray@aol.com
# ..           ...        ...       ...                          ...
# 609           55       Mark    Taylor         mark.taylor@yahoo.au
# 610           52       Emma     Jones       emma_jones@hotmail.com
# 611           33      Ellie  Sullivan       ellie.sullivan@shaw.ca
# 612           20        Dan    Miller          dmiller@comcast.com
# 613           53       Phil    Hughes        phil.hughes@gmail.com
#
#      invoice_id         invoice_date  total
# 0             1  2017-01-03 00:00:00  15.84
# 1             2  2017-01-03 00:00:00   9.90
# 2             3  2017-01-05 00:00:00   1.98
# 3             4  2017-01-06 00:00:00   7.92
# 4             5  2017-01-07 00:00:00  16.83
# ..          ...                  ...    ...
# 609         610  2020-12-21 00:00:00   6.93
# 610         611  2020-12-27 00:00:00   1.98
# 611         612  2020-12-27 00:00:00  11.88
# 612         613  2020-12-29 00:00:00   8.91
# 613         614  2020-12-30 00:00:00  12.87
#
# [614 rows x 7 columns]

# %% [markdown]
# Aliasing in Joins:

# %%
query = """

SELECT 
    t.track_id, t.name AS track_name, t.composer, t.name, g.name as genre
FROM 
    track AS t
JOIN 
    genre AS g
    ON t.genre_id = g.genre_id
LIMIT
    5;
"""

pd.read_sql_query(query,connection)
# Out:
#    track_id                               track_name  \
# 0         1  For Those About To Rock (We Salute You)
# 1         2                        Balls to the Wall
# 2         3                          Fast As a Shark
# 3         4                        Restless and Wild
# 4         5                     Princess of the Dawn
#
#                                             composer  \
# 0          Angus Young, Malcolm Young, Brian Johnson
# 1                                               None
# 2  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 3  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 4                         Deaffy & R.A. Smith-Diesel
#
#                                       name genre
# 0  For Those About To Rock (We Salute You)  Rock
# 1                        Balls to the Wall  Rock
# 2                          Fast As a Shark  Rock
# 3                        Restless and Wild  Rock
# 4                     Princess of the Dawn  Rock

# %% [markdown]
# ## Joins and Other Clauses

# %% [markdown]
# Joining and GROUP BY:

# %%
query = """

SELECT 
    genre.name AS genre, 
    COUNT(*) AS num_of_tracks
FROM 
    genre
JOIN 
    track
    ON genre.genre_id = track.genre_id
GROUP BY
    genre.name

"""

pd.read_sql_query(query,connection)
# Out:
#                  genre  num_of_tracks
# 0          Alternative             40
# 1   Alternative & Punk            332
# 2                Blues             81
# 3           Bossa Nova             15
# 4            Classical             74
# 5               Comedy             17
# 6                Drama             64
# 7       Easy Listening             24
# 8    Electronica/Dance             30
# 9          Heavy Metal             28
# 10         Hip Hop/Rap             35
# 11                Jazz            130
# 12               Latin            579
# 13               Metal            374
# 14               Opera              1
# 15                 Pop             48
# 16            R&B/Soul             61
# 17              Reggae             58
# 18                Rock           1297
# 19       Rock And Roll             12
# 20    Sci Fi & Fantasy             26
# 21     Science Fiction             13
# 22          Soundtrack             43
# 23            TV Shows             93
# 24               World             28

# %% [markdown]
# Joining multiple tables:

# %%
query = """

SELECT 
    i.*, 
    e.first_name
FROM 
    invoice as i
JOIN 
    customer AS c
    ON 
    i.customer_id = c.customer_id
JOIN 
    employee AS e
    ON 
    c.support_rep_id = e.employee_id;

"""

pd.read_sql_query(query,connection)
# Out:
#      invoice_id  customer_id         invoice_date       billing_address  \
# 0             1           18  2017-01-03 00:00:00          627 Broadway
# 1             2           30  2017-01-03 00:00:00      230 Elgin Street
# 2             3           40  2017-01-05 00:00:00        8, Rue Hanovre
# 3             4           18  2017-01-06 00:00:00          627 Broadway
# 4             5           27  2017-01-07 00:00:00       1033 N Park Ave
# ..          ...          ...                  ...                   ...
# 609         610           55  2020-12-21 00:00:00     421 Bourke Street
# 610         611           52  2020-12-27 00:00:00     202 Hoxton Street
# 611         612           33  2020-12-27 00:00:00        5112 48 Street
# 612         613           20  2020-12-29 00:00:00  541 Del Medio Avenue
# 613         614           53  2020-12-30 00:00:00          113 Lupus St
#
#       billing_city billing_state billing_country billing_postal_code  total  \
# 0         New York            NY             USA          10012-2612  15.84
# 1           Ottawa            ON          Canada             K2P 1L7   9.90
# 2            Paris          None          France               75002   1.98
# 3         New York            NY             USA          10012-2612   7.92
# 4           Tucson            AZ             USA               85719  16.83
# ..             ...           ...             ...                 ...    ...
# 609         Sidney           NSW       Australia                2010   6.93
# 610         London          None  United Kingdom              N1 5LH   1.98
# 611    Yellowknife            NT          Canada             X1A 1N6  11.88
# 612  Mountain View            CA             USA           94040-111   8.91
# 613         London          None  United Kingdom            SW1V 3EN  12.87
#
#     first_name
# 0         Jane
# 1         Jane
# 2     Margaret
# 3         Jane
# 4     Margaret
# ..         ...
# 609   Margaret
# 610       Jane
# 611       Jane
# 612   Margaret
# 613       Jane
#
# [614 rows x 10 columns]

# %% [markdown]
# ## Less Common Joins

# %% [markdown]
# Self-joins:

# %%
query = """

   SELECT e1.employee_id,
          e2.employee_id AS manager_id,
          e1.first_name || " " || e1.last_name AS report,
          e2.first_name || " " || e2.last_name AS manager
     FROM employee AS e1
LEFT JOIN employee AS e2
       ON e1.reports_to = e2.employee_id;

"""

pd.read_sql_query(query,connection)
# Out:
#    employee_id  manager_id            report           manager
# 0            1         NaN      Andrew Adams              None
# 1            2         1.0     Nancy Edwards      Andrew Adams
# 2            3         2.0      Jane Peacock     Nancy Edwards
# 3            4         2.0     Margaret Park     Nancy Edwards
# 4            5         2.0     Steve Johnson     Nancy Edwards
# 5            6         1.0  Michael Mitchell      Andrew Adams
# 6            7         6.0       Robert King  Michael Mitchell
# 7            8         6.0    Laura Callahan  Michael Mitchell

# %% [markdown]
# CROSS JOIN:

# %%
query = """

SELECT 
    c1.first_name, 
    c1.last_name, 
    c1.email, 
    c2.first_name, 
    c2.last_name, 
    c2.email
FROM 
    customer AS c1
CROSS JOIN 
    customer AS c2
WHERE 
    c1.customer_id != c2.customer_id
LIMIT
    5;
    
"""

pd.read_sql_query(query,connection)
# Out:
#   first_name  last_name                 email first_name    last_name  \
# 0       Luís  Gonçalves  luisg@embraer.com.br     Leonie       Köhler
# 1       Luís  Gonçalves  luisg@embraer.com.br   François     Tremblay
# 2       Luís  Gonçalves  luisg@embraer.com.br      Bjørn       Hansen
# 3       Luís  Gonçalves  luisg@embraer.com.br  František  Wichterlová
# 4       Luís  Gonçalves  luisg@embraer.com.br     Helena         Holý
#
#                       email
# 0     leonekohler@surfeu.de
# 1       ftremblay@gmail.com
# 2     bjorn.hansen@yahoo.no
# 3  frantisekw@jetbrains.com
# 4           hholy@gmail.com

# %% [markdown]
# Joining on Conditions:

# %%
query = """

SELECT 
    t.track_id, 
    t.name, 
    COUNT(i.invoice_id) AS no_of_purchases
FROM 
    track AS t
LEFT JOIN 
    invoice_line AS il
    ON 
    t.track_id = il.track_id
LEFT JOIN 
    invoice AS i
    ON il.invoice_id = i.invoice_id AND SUBSTRING(i.invoice_date,1,4) = '2020'
GROUP BY 
    t.track_id, t.name
LIMIT
10;
"""

pd.read_sql_query(query,connection)
# Out:
#    track_id                                     name  no_of_purchases
# 0         1  For Those About To Rock (We Salute You)                1
# 1         2                        Balls to the Wall                0
# 2         3                          Fast As a Shark                1
# 3         4                        Restless and Wild                2
# 4         5                     Princess of the Dawn                0
# 5         6                    Put The Finger On You                3
# 6         7                          Let's Get It Up                0
# 7         8                         Inject The Venom                1
# 8         9                               Snowballed                2
# 9        10                               Evil Walks                2

# %%
query = """

SELECT
i1.invoice_id, i1.invoice_date, i1.total,
ROUND(SUM(i2.total),2) AS running_total
FROM
invoice as i1
JOIN invoice AS i2
ON i1.invoice_id >= i2.invoice_id AND i1.invoice_date >= i2.invoice_date
GROUP BY
i1.invoice_id, i1.invoice_date, i1.total
LIMIT
10;

"""

pd.read_sql_query(query,connection)
# Out:
#    invoice_id         invoice_date  total  running_total
# 0           1  2017-01-03 00:00:00  15.84          15.84
# 1           2  2017-01-03 00:00:00   9.90          25.74
# 2           3  2017-01-05 00:00:00   1.98          27.72
# 3           4  2017-01-06 00:00:00   7.92          35.64
# 4           5  2017-01-07 00:00:00  16.83          52.47
# 5           6  2017-01-10 00:00:00   1.98          54.45
# 6           7  2017-01-12 00:00:00  10.89          65.34
# 7           8  2017-01-13 00:00:00   9.90          75.24
# 8           9  2017-01-18 00:00:00   8.91          84.15
# 9          10  2017-01-18 00:00:00   1.98          86.13

# %% [markdown]
# ## Set Operators

# %% [markdown]
# UNION:

# %%
query = """

SELECT *
FROM invoice_2017q1_2018q2

UNION

SELECT *
FROM invoice_2018q1_2018q4

"""

pd.read_sql_query(query,connection)
# Out:
#      invoice_id  customer_id         invoice_date     billing_address  \
# 0             1           18  2017-01-03 00:00:00        627 Broadway
# 1             2           30  2017-01-03 00:00:00    230 Elgin Street
# 2             3           40  2017-01-05 00:00:00      8, Rue Hanovre
# 3             4           18  2017-01-06 00:00:00        627 Broadway
# 4             5           27  2017-01-07 00:00:00     1033 N Park Ave
# ..          ...          ...                  ...                 ...
# 300         301           34  2018-12-15 00:00:00  Rua da Assunção 53
# 301         302           40  2018-12-18 00:00:00      8, Rue Hanovre
# 302         303           28  2018-12-21 00:00:00         302 S 700 E
# 303         304           56  2018-12-23 00:00:00  307 Macacha Güemes
# 304         305           40  2018-12-26 00:00:00      8, Rue Hanovre
#
#        billing_city billing_state billing_country billing_postal_code  total
# 0          New York            NY             USA          10012-2612  15.84
# 1            Ottawa            ON          Canada             K2P 1L7   9.90
# 2             Paris          None          France               75002   1.98
# 3          New York            NY             USA          10012-2612   7.92
# 4            Tucson            AZ             USA               85719  16.83
# ..              ...           ...             ...                 ...    ...
# 300          Lisbon          None        Portugal                None   7.92
# 301           Paris          None          France               75002   3.96
# 302  Salt Lake City            UT             USA               84102   9.90
# 303    Buenos Aires          None       Argentina                1106   6.93
# 304           Paris          None          France               75002  14.85
#
# [305 rows x 9 columns]

# %% [markdown]
# UNION ALL:

# %%
query = """

SELECT invoice_id, customer_id, invoice_date, total
FROM invoice_2017q1_2018q2

UNION ALL

SELECT invoice_id, customer_id, invoice_date, total
FROM invoice_2018q1_2018q4;

"""

pd.read_sql_query(query,connection)
# Out:
#      invoice_id  customer_id         invoice_date  total
# 0             1           18  2017-01-03 00:00:00  15.84
# 1             2           30  2017-01-03 00:00:00   9.90
# 2             3           40  2017-01-05 00:00:00   1.98
# 3             4           18  2017-01-06 00:00:00   7.92
# 4             5           27  2017-01-07 00:00:00  16.83
# ..          ...          ...                  ...    ...
# 391         301           34  2018-12-15 00:00:00   7.92
# 392         302           40  2018-12-18 00:00:00   3.96
# 393         303           28  2018-12-21 00:00:00   9.90
# 394         304           56  2018-12-23 00:00:00   6.93
# 395         305           40  2018-12-26 00:00:00  14.85
#
# [396 rows x 4 columns]

# %% [markdown]
# INTERSECT:

# %%
query = """

SELECT *
     FROM invoice_2017q1_2018q2

INTERSECT

   SELECT *
     FROM invoice_2018q1_2018q4
     
"""

pd.read_sql_query(query,connection)
# Out:
#     invoice_id  customer_id         invoice_date            billing_address  \
# 0          155           59  2018-01-02 00:00:00          3,Raj Bhavan Road
# 1          156           10  2018-01-03 00:00:00  Rua Dr. Falcão Filho, 155
# 2          157           57  2018-01-04 00:00:00            Calle Lira, 198
# 3          158           57  2018-01-07 00:00:00            Calle Lira, 198
# 4          159           20  2018-01-08 00:00:00       541 Del Medio Avenue
# ..         ...          ...                  ...                        ...
# 86         241           45  2018-06-18 00:00:00          Erzsébet krt. 58.
# 87         242           36  2018-06-18 00:00:00         Tauentzienstraße 8
# 88         243            6  2018-06-23 00:00:00              Rilská 3174/6
# 89         244           53  2018-06-23 00:00:00               113 Lupus St
# 90         245           20  2018-06-30 00:00:00       541 Del Medio Avenue
#
#      billing_city billing_state billing_country billing_postal_code  total
# 0       Bangalore          None           India              560001   8.91
# 1       São Paulo            SP          Brazil           01007-010  10.89
# 2        Santiago          None           Chile                None   0.99
# 3        Santiago          None           Chile                None   5.94
# 4   Mountain View            CA             USA           94040-111   5.94
# ..            ...           ...             ...                 ...    ...
# 86       Budapest          None         Hungary              H-1073   1.98
# 87         Berlin          None         Germany               10789   9.90
# 88         Prague          None  Czech Republic               14300  10.89
# 89         London          None  United Kingdom            SW1V 3EN   4.95
# 90  Mountain View            CA             USA           94040-111   2.97
#
# [91 rows x 9 columns]

# %% [markdown]
# EXCEPT:

# %%
query = """

SELECT *
  FROM invoice_2017q1_2018q2

EXCEPT

SELECT *
FROM invoice_2018q1_2018q4

ORDER BY invoice_date DESC;

"""

pd.read_sql_query(query,connection)
# Out:
#      invoice_id  customer_id         invoice_date  \
# 0           154           39  2017-12-17 00:00:00
# 1           153            1  2017-12-14 00:00:00
# 2           152           12  2017-12-12 00:00:00
# 3           151           35  2017-12-06 00:00:00
# 4           150           22  2017-12-01 00:00:00
# ..          ...          ...                  ...
# 149           5           27  2017-01-07 00:00:00
# 150           4           18  2017-01-06 00:00:00
# 151           3           40  2017-01-05 00:00:00
# 152           1           18  2017-01-03 00:00:00
# 153           2           30  2017-01-03 00:00:00
#
#                               billing_address         billing_city  \
# 0                               4, Rue Milton                Paris
# 1             Av. Brigadeiro Faria Lima, 2170  São José dos Campos
# 2                            Praça Pio X, 119       Rio de Janeiro
# 3    Rua dos Campeões Europeus de Viena, 4350                Porto
# 4                            120 S Orange Ave              Orlando
# ..                                        ...                  ...
# 149                           1033 N Park Ave               Tucson
# 150                              627 Broadway             New York
# 151                            8, Rue Hanovre                Paris
# 152                              627 Broadway             New York
# 153                          230 Elgin Street               Ottawa
#
#     billing_state billing_country billing_postal_code  total
# 0            None          France               75009   2.97
# 1              SP          Brazil           12227-000  13.86
# 2              RJ          Brazil           20040-020   5.94
# 3            None        Portugal                None   2.97
# 4              FL             USA               32801   2.97
# ..            ...             ...                 ...    ...
# 149            AZ             USA               85719  16.83
# 150            NY             USA          10012-2612   7.92
# 151          None          France               75002   1.98
# 152            NY             USA          10012-2612  15.84
# 153            ON          Canada             K2P 1L7   9.90
#
# [154 rows x 9 columns]
